# %% [markdown]
# # Test Analysis

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import Polynomial
from sklearn.metrics import mean_squared_error
    
import mydata
import performance
from performance import PerformanceMeasure, PerformanceOptimisation
from bayes import BayesianRegression

# %% [markdown]
# # UTKFace

# %%
db = "UTKFace"
root = f"../../dataset/AAAI 2025/{db}/"
df_valid_ef3 = mydata.load_and_process_csv(f"{root}evaluation/df_test_efficientnet.csv", True)
df_valid_resnet = mydata.load_and_process_csv(f"{root}evaluation/df_test_resnet.csv", True)
df_valid_vgg = mydata.load_and_process_csv(f"{root}evaluation/df_test_vgg.csv", True)

# %%
po_efficientnet = PerformanceOptimisation(df_valid_ef3, db, "Efficientnet")
po_resnet = PerformanceOptimisation(df_valid_resnet, db, "ResNet")
po_vgg = PerformanceOptimisation(df_valid_vgg, db, "VGG")

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning) # To adovid error message related one labels
    
    fig, ax = plt.subplots(1, 3, figsize=(18, 5))
    po_efficientnet.check_batch_size(ax[0])
    po_resnet.check_batch_size(ax[1])
    po_vgg.check_batch_size(ax[2], b_start = 10, b_end = 360, b_step = 10)
    plt.tight_layout()
    plt.show()

# %%
# Correlation check
po_efficientnet.check_optimal_batch_correlation(batch_size=100)
po_resnet.check_optimal_batch_correlation(batch_size=100)
po_vgg.check_optimal_batch_correlation(batch_size=100)
# Out:
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000 -0.708506 -0.501514 -0.566392  0.566392  0.501514
# ACC      -0.708506  1.000000  0.869620  0.594261 -0.594261 -0.869620
# TPR      -0.501514  0.869620  1.000000  0.150118 -0.150118 -1.000000
# TNR      -0.566392  0.594261  0.150118  1.000000 -1.000000 -0.150118
# FPR       0.566392 -0.594261 -0.150118 -1.000000  1.000000  0.150118
# FNR       0.501514 -0.869620 -1.000000 -0.150118  0.150118  1.000000
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000 -0.426442  0.000523 -0.615947  0.615947 -0.000523
# ACC      -0.426442  1.000000  0.808550  0.643380 -0.643380 -0.808550
# TPR       0.000523  0.808550  1.000000  0.156757 -0.156757 -1.000000
# TNR      -0.615947  0.643380  0.156757  1.000000 -1.000000 -0.156757
# FPR       0.615947 -0.643380 -0.156757 -1.000000  1.000000  0.156757
# FNR      -0.000523 -0.808550 -1.000000 -0.156757  0.156757  1.000000
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000 -0.618870  0.302721 -0.781694  0.781694 -0.302721
# ACC      -0.618870  1.000000  0.386657  0.715871 -0.715871 -0.386657
# TPR       0.302721  0.386657  1.000000 -0.289075  0.289075 -1.000000
# TNR      -0.781694  0.715871 -0.289075  1.000000 -1.000000  0.289075
# FPR       0.781694 -0.715871  0.289075 -1.000000  1.000000 -0.289075
# FNR      -0.302721 -0.386657 -1.000000  0.289075 -0.289075  1.000000

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
po_efficientnet.display_distance_performance(ax[0])
po_resnet.display_distance_performance(ax[1])
po_vgg.display_distance_performance(ax[2])
plt.tight_layout()
plt.show()

# %% [markdown]
# # CelebA

# %%
db = "CelebA"
root = f"../../dataset/AAAI 2025/{db}/"
df_valid_ef3 = mydata.load_and_process_csv(f"{root}evaluation/df_test_efficientnet.csv", True)
df_valid_resnet = mydata.load_and_process_csv(f"{root}evaluation/df_test_resnet.csv", True)
df_valid_vgg = mydata.load_and_process_csv(f"{root}evaluation/df_test_vgg.csv", True)

# %%
po_efficientnet = PerformanceOptimisation(df_valid_ef3, db, "Efficientnet")
po_resnet = PerformanceOptimisation(df_valid_resnet, db, "ResNet")
po_vgg = PerformanceOptimisation(df_valid_vgg, db, "VGG")

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning) # To adovid error message related one labels
    
    fig, ax = plt.subplots(1, 3, figsize=(18, 5))
    po_efficientnet.check_batch_size(ax[0])
    po_resnet.check_batch_size(ax[1])
    po_vgg.check_batch_size(ax[2], b_start = 10, b_end = 360, b_step = 10)
    plt.tight_layout()
    plt.show()

# %%
# Correlation check
po_efficientnet.check_optimal_batch_correlation(batch_size=100)
po_resnet.check_optimal_batch_correlation(batch_size=100)
po_vgg.check_optimal_batch_correlation(batch_size=100)
# Out:
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000  0.097556 -0.462632  0.584195 -0.584195  0.462632
# ACC       0.097556  1.000000  0.679280  0.475872 -0.475872 -0.679280
# TPR      -0.462632  0.679280  1.000000 -0.291096  0.291096 -1.000000
# TNR       0.584195  0.475872 -0.291096  1.000000 -1.000000  0.291096
# FPR      -0.584195 -0.475872  0.291096 -1.000000  1.000000 -0.291096
# FNR       0.462632 -0.679280 -1.000000  0.291096 -0.291096  1.000000
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000  0.252782 -0.319111  0.544496 -0.544496  0.319111
# ACC       0.252782  1.000000  0.669945  0.576638 -0.576638 -0.669945
# TPR      -0.319111  0.669945  1.000000 -0.190732  0.190732 -1.000000
# TNR       0.544496  0.576638 -0.190732  1.000000 -1.000000  0.190732
# FPR      -0.544496 -0.576638  0.190732 -1.000000  1.000000 -0.190732
# FNR       0.319111 -0.669945 -1.000000  0.190732 -0.190732  1.000000
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000  0.252782 -0.319111  0.544496 -0.544496  0.319111
# ACC       0.252782  1.000000  0.669945  0.576638 -0.576638 -0.669945
# TPR      -0.319111  0.669945  1.000000 -0.190732  0.190732 -1.000000
# TNR       0.544496  0.576638 -0.190732  1.000000 -1.000000  0.190732
# FPR      -0.544496 -0.576638  0.190732 -1.000000  1.000000 -0.190732
# FNR       0.319111 -0.669945 -1.000000  0.190732 -0.190732  1.000000

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
po_efficientnet.display_distance_performance(ax[0])
po_resnet.display_distance_performance(ax[1])
po_vgg.display_distance_performance(ax[2])
plt.tight_layout()
plt.show()

# %% [markdown]
# # HAM10000

# %%
db = "HAM"
root = f"../../dataset/AAAI 2025/{db}/"
df_valid_ef3 = mydata.load_and_process_csv(f"{root}evaluation/df_test_efficientnet.csv", True)
df_valid_resnet = mydata.load_and_process_csv(f"{root}evaluation/df_test_resnet.csv", True)
df_valid_vgg = mydata.load_and_process_csv(f"{root}evaluation/df_test_vgg.csv", True)

# %%
po_efficientnet = PerformanceOptimisation(df_valid_ef3, db, "Efficientnet")
po_resnet = PerformanceOptimisation(df_valid_resnet, db, "ResNet")
po_vgg = PerformanceOptimisation(df_valid_vgg, db, "VGG")

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=UserWarning) # To adovid error message related one labels
    
    fig, ax = plt.subplots(1, 3, figsize=(18, 5))
    po_efficientnet.check_batch_size(ax[0])
    po_resnet.check_batch_size(ax[1])
    po_vgg.check_batch_size(ax[2], b_start = 10, b_end = 360, b_step = 10)
    plt.tight_layout()
    plt.show()

# %%
# Correlation check
po_efficientnet.check_optimal_batch_correlation(batch_size=50)
po_resnet.check_optimal_batch_correlation(batch_size=50)
po_vgg.check_optimal_batch_correlation(batch_size=50)
# Out:
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000 -0.639244  0.407615 -0.864826  0.864826 -0.407615
# ACC      -0.639244  1.000000 -0.045491  0.854632 -0.854632  0.045491
# TPR       0.407615 -0.045491  1.000000 -0.342462  0.342462 -1.000000
# TNR      -0.864826  0.854632 -0.342462  1.000000 -1.000000  0.342462
# FPR       0.864826 -0.854632  0.342462 -1.000000  1.000000 -0.342462
# FNR      -0.407615  0.045491 -1.000000  0.342462 -0.342462  1.000000
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000 -0.612416  0.413109 -0.868857  0.868857 -0.413109
# ACC      -0.612416  1.000000  0.026646  0.780312 -0.780312 -0.026646
# TPR       0.413109  0.026646  1.000000 -0.348772  0.348772 -1.000000
# TNR      -0.868857  0.780312 -0.348772  1.000000 -1.000000  0.348772
# FPR       0.868857 -0.780312  0.348772 -1.000000  1.000000 -0.348772
# FNR      -0.413109 -0.026646 -1.000000  0.348772 -0.348772  1.000000
#           distance       ACC       TPR       TNR       FPR       FNR
# distance  1.000000 -0.744420  0.361974 -0.777496  0.777496 -0.361974
# ACC      -0.744420  1.000000 -0.117646  0.894787 -0.894787  0.117646
# TPR       0.361974 -0.117646  1.000000 -0.287436  0.287436 -1.000000
# TNR      -0.777496  0.894787 -0.287436  1.000000 -1.000000  0.287436
# FPR       0.777496 -0.894787  0.287436 -1.000000  1.000000 -0.287436
# FNR      -0.361974  0.117646 -1.000000  0.287436 -0.287436  1.000000

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
po_efficientnet.display_distance_performance(ax[0])
po_resnet.display_distance_performance(ax[1])
po_vgg.display_distance_performance(ax[2])
plt.tight_layout()
plt.show()
